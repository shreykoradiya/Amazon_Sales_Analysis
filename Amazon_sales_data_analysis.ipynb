# %% [markdown]
# ## Amazon sales data analysis using python
#
# ### Import necessary libraries

# %%
import numpy as np    # numerical data analysis
import pandas as pd   # File read write and processing

import matplotlib.pyplot as plt  # plotting and visualization

# %%
data = pd.read_csv("/content/Amazon_Sale_Report.csv")

# %%
data.shape
# Out:
# (128976, 21)

# %% [markdown]
# The data has 128976 rows and 21 columns

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
data.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# 0  ...       INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1  ...       INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2  ...       INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
# 3  ...       INR  753.33   PUDUCHERRY   PUDUCHERRY         605008.0
# 4  ...       INR  574.00      CHENNAI   TAMIL NADU         600073.0
#
#    ship-country    B2B  fulfilled-by New  PendingS
# 0            IN  False     Easy Ship NaN       NaN
# 1            IN  False     Easy Ship NaN       NaN
# 2            IN   True           NaN NaN       NaN
# 3            IN  False     Easy Ship NaN       NaN
# 4            IN  False           NaN NaN       NaN
#
# [5 rows x 21 columns]

# %%
data = data.drop('index', axis=1)

# %%
data
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128971  406-6001380-7673107  05-31-22                       Shipped
# 128972  402-9551604-7544318  05-31-22                       Shipped
# 128973  407-9547469-3152358  05-31-22                       Shipped
# 128974  402-6184140-0545956  05-31-22                       Shipped
# 128975  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# 1        Merchant     Amazon.in           Standard     Shirt  3XL
# 2          Amazon     Amazon.in          Expedited     Shirt   XL
# 3        Merchant     Amazon.in           Standard   Blazzer    L
# 4          Amazon     Amazon.in          Expedited  Trousers  3XL
# ...           ...           ...                ...       ...  ...
# 128971     Amazon     Amazon.in          Expedited     Shirt   XL
# 128972     Amazon     Amazon.in          Expedited   T-shirt    M
# 128973     Amazon     Amazon.in          Expedited   Blazzer  XXL
# 128974     Amazon     Amazon.in          Expedited   T-shirt   XS
# 128975     Amazon     Amazon.in          Expedited   T-shirt    S
#
#        Courier Status  Qty currency   Amount    ship-city    ship-state  \
# 0          On the Way    0      INR   647.62       MUMBAI   MAHARASHTRA
# 1             Shipped    1      INR   406.00    BENGALURU     KARNATAKA
# 2             Shipped    1      INR   329.00  NAVI MUMBAI   MAHARASHTRA
# 3          On the Way    0      INR   753.33   PUDUCHERRY    PUDUCHERRY
# 4             Shipped    1      INR   574.00      CHENNAI    TAMIL NADU
# ...               ...  ...      ...      ...          ...           ...
# 128971        Shipped    1      INR   517.00    HYDERABAD     TELANGANA
# 128972        Shipped    1      INR   999.00     GURUGRAM       HARYANA
# 128973        Shipped    1      INR   690.00    HYDERABAD     TELANGANA
# 128974        Shipped    1      INR  1199.00        Halol       Gujarat
# 128975        Shipped    1      INR   696.00       Raipur  CHHATTISGARH
#
#         ship-postal-code ship-country    B2B fulfilled-by  New  PendingS
# 0               400081.0           IN  False    Easy Ship  NaN       NaN
# 1               560085.0           IN  False    Easy Ship  NaN       NaN
# 2               410210.0           IN   True          NaN  NaN       NaN
# 3               605008.0           IN  False    Easy Ship  NaN       NaN
# 4               600073.0           IN  False          NaN  NaN       NaN
# ...                  ...          ...    ...          ...  ...       ...
# 128971          500013.0           IN  False          NaN  NaN       NaN
# 128972          122004.0           IN  False          NaN  NaN       NaN
# 128973          500049.0           IN  False          NaN  NaN       NaN
# 128974          389350.0           IN  False          NaN  NaN       NaN
# 128975          492014.0           IN  False          NaN  NaN       NaN
#
# [128976 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  object
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
#  15  ship-country        128941 non-null  object
#  16  B2B                 128976 non-null  bool
#  17  fulfilled-by        39263 non-null   object
#  18  New                 0 non-null       float64
#  19  PendingS            0 non-null       float64
# dtypes: bool(1), float64(4), int64(1), object(14)
# memory usage: 18.8+ MB

# %%
data = data.drop(['New', 'PendingS'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  object
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
#  15  ship-country        128941 non-null  object
#  16  B2B                 128976 non-null  bool
#  17  fulfilled-by        39263 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(14)
# memory usage: 16.9+ MB

# %%
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# <ipython-input-14-1a72a8b5b870>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  datetime64[ns]
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
#  15  ship-country        128941 non-null  object
#  16  B2B                 128976 non-null  bool
#  17  fulfilled-by        39263 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(13)
# memory usage: 16.9+ MB

# %%
data['Date'].min(), data['Date'].max()
# Out:
# (Timestamp('2022-03-31 00:00:00'), Timestamp('2022-06-29 00:00:00'))

# %% [markdown]
# ### Status column

# %%
data['Status'].unique()
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
data.value_counts(['Status'])
# Out:
# Status
# Shipped                          77815
# Shipped - Delivered to Buyer     28756
# Cancelled                        18334
# Shipped - Returned to Seller      1954
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
data.value_counts(['Status']).plot(kind='bar')
# Out:
# <Axes: xlabel='Status'>

# %%
status_count = data.value_counts(['Status'])

status_count = status_count.reset_index()

# %%
type(status_count)
# Out:
# pandas.core.frame.DataFrame

# %%
status_count['percentage'] = np.round(100*status_count['count']/sum(status_count['count']),2)

# %%
status_count
# Out:
#                            Status  count  percentage
# 0                         Shipped  77815       60.33
# 1    Shipped - Delivered to Buyer  28756       22.30
# 2                       Cancelled  18334       14.22
# 3    Shipped - Returned to Seller   1954        1.52
# 4             Shipped - Picked Up    973        0.75
# 5                         Pending    658        0.51
# 6   Pending - Waiting for Pick Up    281        0.22
# 7   Shipped - Returning to Seller    145        0.11
# 8      Shipped - Out for Delivery     35        0.03
# 9     Shipped - Rejected by Buyer     11        0.01
# 10                       Shipping      8        0.01
# 11      Shipped - Lost in Transit      5        0.00
# 12              Shipped - Damaged      1        0.00

# %%
status_count[['Status','percentage']].set_index('Status').plot(kind='bar')
# Out:
# <Axes: xlabel='Status'>

# %% [markdown]
# ### Fulfilment and fulfilled-by

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  datetime64[ns]
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
#  15  ship-country        128941 non-null  object
#  16  B2B                 128976 non-null  bool
#  17  fulfilled-by        39263 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(13)
# memory usage: 16.9+ MB

# %%
data['Fulfilment'].unique()
# Out:
# array(['Merchant', 'Amazon'], dtype=object)

# %%
data['Fulfilment'].value_counts()
# Out:
# Fulfilment
# Amazon      89713
# Merchant    39263
# Name: count, dtype: int64

# %%
fulfilment_df = data['Fulfilment'].value_counts().reset_index()

fulfilment_df['percentage'] = np.round(100*fulfilment_df['count']/sum(fulfilment_df['count']),2)

# %%
fulfilment_df
# Out:
#   Fulfilment  count  percentage
# 0     Amazon  89713       69.56
# 1   Merchant  39263       30.44

# %%
data[['Fulfilment', 'fulfilled-by']]
# Out:
#        Fulfilment fulfilled-by
# 0        Merchant    Easy Ship
# 1        Merchant    Easy Ship
# 2          Amazon          NaN
# 3        Merchant    Easy Ship
# 4          Amazon          NaN
# ...           ...          ...
# 128971     Amazon          NaN
# 128972     Amazon          NaN
# 128973     Amazon          NaN
# 128974     Amazon          NaN
# 128975     Amazon          NaN
#
# [128976 rows x 2 columns]

# %%
data['fulfilled-by'].isnull().sum()
# Out:
# np.int64(89713)

# %%
data['fulfilled-by'].value_counts()
# Out:
# fulfilled-by
# Easy Ship    39263
# Name: count, dtype: int64

# %% [markdown]
# ### Sales channel

# %%
data['Sales Channel'].value_counts()
# Out:
# Sales Channel
# Amazon.in     128852
# Non-Amazon       124
# Name: count, dtype: int64

# %%
data[data['Sales Channel']=='Non-Amazon']
# Out:
#                    Order ID       Date   Status Fulfilment Sales Channel  \
# 938     S02-5278980-4327051 2022-04-30  Shipped     Amazon    Non-Amazon
# 1058    S02-9107114-0460608 2022-04-30  Shipped     Amazon    Non-Amazon
# 3632    S02-1006261-5356758 2022-04-28  Shipped     Amazon    Non-Amazon
# 3633    S02-3681731-6111841 2022-04-28  Shipped     Amazon    Non-Amazon
# 3635    S02-1926028-4838217 2022-04-28  Shipped     Amazon    Non-Amazon
# ...                     ...        ...      ...        ...           ...
# 118100  S02-9176732-4357939 2022-06-08  Shipped     Amazon    Non-Amazon
# 124617  S02-2059602-9568060 2022-06-04  Shipped     Amazon    Non-Amazon
# 124618  S02-3811761-8377519 2022-06-04  Shipped     Amazon    Non-Amazon
# 124620  S02-5216693-3162561 2022-06-04  Shipped     Amazon    Non-Amazon
# 124622  S02-7324586-1573702 2022-06-04  Shipped     Amazon    Non-Amazon
#
#        ship-service-level Category  Size Courier Status  Qty currency  Amount  \
# 938              Standard   Wallet  Free      Unshipped   15      NaN     NaN
# 1058             Standard  T-shirt    XL      Unshipped    2      NaN     NaN
# 3632             Standard    Shirt     L      Unshipped    9      NaN     NaN
# 3633             Standard    Shirt     L      Unshipped    1      NaN     NaN
# 3635             Standard    Shirt    XS      Unshipped    1      NaN     NaN
# ...                   ...      ...   ...            ...  ...      ...     ...
# 118100           Standard  T-shirt     M      Unshipped    1      NaN     NaN
# 124617           Standard    Shirt     S      Unshipped    1      NaN     NaN
# 124618           Standard  T-shirt    XS      Unshipped    2      NaN     NaN
# 124620           Standard  T-shirt   XXL      Unshipped    1      NaN     NaN
# 124622           Standard  T-shirt   3XL      Unshipped    1      NaN     NaN
#
#        ship-city ship-state  ship-postal-code ship-country    B2B fulfilled-by
# 938        Surat    Gujarat          394210.0           IN  False          NaN
# 1058       Surat    Gujarat          394210.0           IN  False          NaN
# 3632       Surat    Gujarat          394210.0           IN  False          NaN
# 3633       Surat    Gujarat          394210.0           IN  False          NaN
# 3635       Surat    Gujarat          394210.0           IN  False          NaN
# ...          ...        ...               ...          ...    ...          ...
# 118100     Surat    Gujarat          394210.0           IN  False          NaN
# 124617     Surat    Gujarat          394210.0           IN  False          NaN
# 124618     Surat    Gujarat          394210.0           IN  False          NaN
# 124620     Surat    Gujarat          394210.0           IN  False          NaN
# 124622     Surat    Gujarat          394210.0           IN  False          NaN
#
# [124 rows x 18 columns]

# %% [markdown]
# ### Ship service level

# %%
data['ship-service-level'].value_counts()
# Out:
# ship-service-level
# Expedited    88630
# Standard     40346
# Name: count, dtype: int64

# %% [markdown]
# ### Category

# %%
data['Category'].value_counts()
# Out:
# Category
# T-shirt     50292
# Shirt       49877
# Blazzer     15500
# Trousers    10616
# Perfume      1157
# Wallet        926
# Socks         440
# Shoes         165
# Watch           3
# Name: count, dtype: int64

# %%
data
# Out:
#                    Order ID       Date                        Status  \
# 0       405-8078784-5731545 2022-04-30                     Cancelled
# 1       171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146 2022-04-30                       Shipped
# 3       403-9615377-8133951 2022-04-30                     Cancelled
# 4       407-1069790-7240320 2022-04-30                       Shipped
# ...                     ...        ...                           ...
# 128971  406-6001380-7673107 2022-05-31                       Shipped
# 128972  402-9551604-7544318 2022-05-31                       Shipped
# 128973  407-9547469-3152358 2022-05-31                       Shipped
# 128974  402-6184140-0545956 2022-05-31                       Shipped
# 128975  408-7436540-8728312 2022-05-31                       Shipped
#
#        Fulfilment Sales Channel ship-service-level  Category Size  \
# 0        Merchant     Amazon.in           Standard   T-shirt    S
# 1        Merchant     Amazon.in           Standard     Shirt  3XL
# 2          Amazon     Amazon.in          Expedited     Shirt   XL
# 3        Merchant     Amazon.in           Standard   Blazzer    L
# 4          Amazon     Amazon.in          Expedited  Trousers  3XL
# ...           ...           ...                ...       ...  ...
# 128971     Amazon     Amazon.in          Expedited     Shirt   XL
# 128972     Amazon     Amazon.in          Expedited   T-shirt    M
# 128973     Amazon     Amazon.in          Expedited   Blazzer  XXL
# 128974     Amazon     Amazon.in          Expedited   T-shirt   XS
# 128975     Amazon     Amazon.in          Expedited   T-shirt    S
#
#        Courier Status  Qty currency   Amount    ship-city    ship-state  \
# 0          On the Way    0      INR   647.62       MUMBAI   MAHARASHTRA
# 1             Shipped    1      INR   406.00    BENGALURU     KARNATAKA
# 2             Shipped    1      INR   329.00  NAVI MUMBAI   MAHARASHTRA
# 3          On the Way    0      INR   753.33   PUDUCHERRY    PUDUCHERRY
# 4             Shipped    1      INR   574.00      CHENNAI    TAMIL NADU
# ...               ...  ...      ...      ...          ...           ...
# 128971        Shipped    1      INR   517.00    HYDERABAD     TELANGANA
# 128972        Shipped    1      INR   999.00     GURUGRAM       HARYANA
# 128973        Shipped    1      INR   690.00    HYDERABAD     TELANGANA
# 128974        Shipped    1      INR  1199.00        Halol       Gujarat
# 128975        Shipped    1      INR   696.00       Raipur  CHHATTISGARH
#
#         ship-postal-code ship-country    B2B fulfilled-by
# 0               400081.0           IN  False    Easy Ship
# 1               560085.0           IN  False    Easy Ship
# 2               410210.0           IN   True          NaN
# 3               605008.0           IN  False    Easy Ship
# 4               600073.0           IN  False          NaN
# ...                  ...          ...    ...          ...
# 128971          500013.0           IN  False          NaN
# 128972          122004.0           IN  False          NaN
# 128973          500049.0           IN  False          NaN
# 128974          389350.0           IN  False          NaN
# 128975          492014.0           IN  False          NaN
#
# [128976 rows x 18 columns]

# %%
category_df = data[['Category', 'Qty', 'Amount']].groupby('Category').aggregate('sum')

# %%
data['Category'].value_counts()
# Out:
# Category
# T-shirt     50292
# Shirt       49877
# Blazzer     15500
# Trousers    10616
# Perfume      1157
# Wallet        926
# Socks         440
# Shoes         165
# Watch           3
# Name: count, dtype: int64

# %%
category_df.sort_values('Qty',ascending=False)
# Out:
#             Qty       Amount
# Category
# T-shirt   45292  39206756.65
# Shirt     45044  21297770.08
# Blazzer   13943  11215104.12
# Trousers   9898   5346286.30
# Perfume    1051    789419.66
# Wallet      863    458408.18
# Socks       399    150757.50
# Shoes       153    124752.76
# Watch         3       915.00

# %%
category_df['avg price'] = np.round(category_df['Amount']/category_df['Qty'], 2)

category_df = category_df.sort_values('Qty', ascending=False)

category_df
# Out:
#             Qty       Amount  avg price
# Category
# T-shirt   45292  39206756.65     865.64
# Shirt     45044  21297770.08     472.82
# Blazzer   13943  11215104.12     804.35
# Trousers   9898   5346286.30     540.14
# Perfume    1051    789419.66     751.11
# Wallet      863    458408.18     531.18
# Socks       399    150757.50     377.84
# Shoes       153    124752.76     815.38
# Watch         3       915.00     305.00

# %% [markdown]
# ### Category and Size

# %%
# How many different types of sizes are there in the t-shirt category in the dataset

t_shirt_df = data[data['Category'] == 'T-shirt']

t_shirt_df
# Out:
#                    Order ID       Date     Status Fulfilment Sales Channel  \
# 0       405-8078784-5731545 2022-04-30  Cancelled   Merchant     Amazon.in
# 5       404-1490984-4578765 2022-04-30    Shipped     Amazon     Amazon.in
# 6       408-5748499-6859555 2022-04-30    Shipped     Amazon     Amazon.in
# 8       407-5443024-5233168 2022-04-30  Cancelled     Amazon     Amazon.in
# 13      408-7955685-3083534 2022-04-30    Shipped     Amazon     Amazon.in
# ...                     ...        ...        ...        ...           ...
# 128969  403-7059995-7618722 2022-05-31    Shipped     Amazon     Amazon.in
# 128970  404-3802633-7250760 2022-05-31  Cancelled     Amazon     Amazon.in
# 128972  402-9551604-7544318 2022-05-31    Shipped     Amazon     Amazon.in
# 128974  402-6184140-0545956 2022-05-31    Shipped     Amazon     Amazon.in
# 128975  408-7436540-8728312 2022-05-31    Shipped     Amazon     Amazon.in
#
#        ship-service-level Category Size Courier Status  Qty currency   Amount  \
# 0                Standard  T-shirt    S     On the Way    0      INR   647.62
# 5               Expedited  T-shirt   XL        Shipped    1      INR   824.00
# 6               Expedited  T-shirt    L        Shipped    1      INR   653.00
# 8               Expedited  T-shirt  3XL      Cancelled    0      NaN      NaN
# 13              Expedited  T-shirt   XS        Shipped    1      INR   657.00
# ...                   ...      ...  ...            ...  ...      ...      ...
# 128969          Expedited  T-shirt   XL        Shipped    1      INR   824.00
# 128970          Expedited  T-shirt    M      Unshipped    1      INR   612.00
# 128972          Expedited  T-shirt    M        Shipped    1      INR   999.00
# 128974          Expedited  T-shirt   XS        Shipped    1      INR  1199.00
# 128975          Expedited  T-shirt    S        Shipped    1      INR   696.00
#
#          ship-city     ship-state  ship-postal-code ship-country    B2B  \
# 0           MUMBAI    MAHARASHTRA          400081.0           IN  False
# 5        GHAZIABAD  UTTAR PRADESH          201102.0           IN  False
# 6       CHANDIGARH     CHANDIGARH          160036.0           IN  False
# 8        HYDERABAD      TELANGANA          500008.0           IN  False
# 13          MUMBAI    MAHARASHTRA          400053.0           IN  False
# ...            ...            ...               ...          ...    ...
# 128969       Delhi          DELHI          110053.0           IN  False
# 128970      MUMBAI    MAHARASHTRA          400017.0           IN  False
# 128972    GURUGRAM        HARYANA          122004.0           IN  False
# 128974       Halol        Gujarat          389350.0           IN  False
# 128975      Raipur   CHHATTISGARH          492014.0           IN  False
#
#        fulfilled-by
# 0         Easy Ship
# 5               NaN
# 6               NaN
# 8               NaN
# 13              NaN
# ...             ...
# 128969          NaN
# 128970          NaN
# 128972          NaN
# 128974          NaN
# 128975          NaN
#
# [50292 rows x 18 columns]

# %%
t_shirt_df.value_counts('Size')
# Out:
# Size
# M      9351
# L      8192
# XL     7573
# S      7509
# XXL    6166
# 3XL    5796
# XS     5515
# 6XL      81
# 5XL      61
# 4XL      48
# Name: count, dtype: int64

# %%
cat_size_df = data[['Category','Size']].value_counts().reset_index()

# %%
cat_size_df = cat_size_df.sort_values(['Category', 'Size'])

# %%
cat_size_df
# Out:
#     Category  Size  count
# 19   Blazzer   3XL   1913
# 14   Blazzer     L   2844
# 15   Blazzer     M   2588
# 17   Blazzer     S   2226
# 16   Blazzer    XL   2380
# 24   Blazzer    XS   1430
# 18   Blazzer   XXL   2119
# 27   Perfume  Free   1157
# 11     Shirt   3XL   5687
# 32     Shirt   4XL    379
# 31     Shirt   5XL    489
# 30     Shirt   6XL    657
# 1      Shirt     L   8924
# 3      Shirt     M   8555
# 10     Shirt     S   5729
# 2      Shirt    XL   8669
# 13     Shirt    XS   3136
# 5      Shirt   XXL   7652
# 33     Shoes  Free    165
# 39     Socks   3XL     64
# 37     Socks     L     72
# 41     Socks     M     58
# 35     Socks     S     74
# 38     Socks    XL     71
# 43     Socks    XS     28
# 36     Socks   XXL     73
# 9    T-shirt   3XL   5796
# 42   T-shirt   4XL     48
# 40   T-shirt   5XL     61
# 34   T-shirt   6XL     81
# 4    T-shirt     L   8192
# 0    T-shirt     M   9351
# 7    T-shirt     S   7509
# 6    T-shirt    XL   7573
# 12   T-shirt    XS   5515
# 8    T-shirt   XXL   6166
# 26  Trousers   3XL   1183
# 23  Trousers     L   1775
# 21  Trousers     M   1821
# 25  Trousers     S   1238
# 20  Trousers    XL   1856
# 28  Trousers    XS    947
# 22  Trousers   XXL   1796
# 29    Wallet  Free    926
# 44     Watch  Free      3

# %%
cat_size_df[cat_size_df['count']==cat_size_df['count'].max()]
# Out:
#   Category Size  count
# 0  T-shirt    M   9351

# %%
data[['Category','Size', 'Qty', 'Amount']].groupby(['Category', 'Size']).aggregate('sum').sort_values('Amount', ascending=False)
# Out:
#                 Qty      Amount
# Category Size
# T-shirt  M     8362  7305376.89
#          L     7396  6354895.10
#          XL    6874  5937447.97
#          S     6704  5832475.07
#          XXL   5604  4763380.90
#          3XL   5287  4529937.41
#          XS    4890  4267824.00
# Shirt    L     8049  3732265.17
#          XL    7837  3631637.95
#          M     7706  3544564.45
#          XXL   6946  3221536.90
#          3XL   5134  2454796.34
#          S     5161  2352487.64
# Blazzer  L     2545  2026215.69
#          M     2327  1880455.49
#          XL    2126  1727110.99
#          S     1963  1602762.85
#          XXL   1945  1572849.94
#          3XL   1758  1406828.11
# Shirt    XS    2787  1240043.34
# Blazzer  XS    1279   998881.05
# Trousers M     1693   942664.71
#          XL    1735   933873.84
#          L     1648   901056.86
#          XXL   1687   883726.99
# Perfume  Free  1051   789419.66
# Trousers 3XL   1121   618261.81
#          S     1146   617436.62
# Shirt    6XL    616   485831.26
# Wallet   Free   863   458408.18
# Trousers XS     868   449265.47
# Shirt    5XL    456   357467.63
#          4XL    352   277139.40
# Shoes    Free   153   124752.76
# T-shirt  6XL     72    90418.07
#          5XL     57    67689.00
#          4XL     46    57312.24
# Socks    XL      64    25879.63
#          L       68    25391.21
#          3XL     60    24332.63
#          XXL     64    23482.96
#          S       67    22598.76
#          M       50    19580.59
#          XS      26     9491.72
# Watch    Free     3      915.00

# %% [markdown]
# ### Courier status

# %%
data['Courier Status']
# Out:
# 0         On the Way
# 1            Shipped
# 2            Shipped
# 3         On the Way
# 4            Shipped
#              ...
# 128971       Shipped
# 128972       Shipped
# 128973       Shipped
# 128974       Shipped
# 128975       Shipped
# Name: Courier Status, Length: 128976, dtype: object

# %%
data['Courier Status'].value_counts()
# Out:
# Courier Status
# Shipped       109486
# On the Way      6870
# Unshipped       6680
# Cancelled       5940
# Name: count, dtype: int64

# %%
Courier_status_df = data['Courier Status'].value_counts().reset_index()

Courier_status_df['percentage'] = np.round(100*Courier_status_df['count']/sum(Courier_status_df['count']),2)

Courier_status_df
# Out:
#   Courier Status   count  percentage
# 0        Shipped  109486       84.89
# 1     On the Way    6870        5.33
# 2      Unshipped    6680        5.18
# 3      Cancelled    5940        4.61

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  datetime64[ns]
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
#  15  ship-country        128941 non-null  object
#  16  B2B                 128976 non-null  bool
#  17  fulfilled-by        39263 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(13)
# memory usage: 16.9+ MB

# %%
data[['Date','Amount']].groupby('Date').aggregate('sum').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df = data[['Date','Amount']].groupby('Date').aggregate('sum')

df[df['Amount']==df['Amount'].max()]
# Out:
#                 Amount
# Date
# 2022-05-04  1209364.17

# %%
df[df['Amount']==df['Amount'].min()]
# Out:
#                Amount
# Date
# 2022-03-31  101683.85

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128976 non-null  object
#  1   Date                128976 non-null  datetime64[ns]
#  2   Status              128976 non-null  object
#  3   Fulfilment          128976 non-null  object
#  4   Sales Channel       128976 non-null  object
#  5   ship-service-level  128976 non-null  object
#  6   Category            128976 non-null  object
#  7   Size                128976 non-null  object
#  8   Courier Status      128976 non-null  object
#  9   Qty                 128976 non-null  int64
#  10  currency            121176 non-null  object
#  11  Amount              121176 non-null  float64
#  12  ship-city           128941 non-null  object
#  13  ship-state          128941 non-null  object
#  14  ship-postal-code    128941 non-null  float64
#  15  ship-country        128941 non-null  object
#  16  B2B                 128976 non-null  bool
#  17  fulfilled-by        39263 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(13)
# memory usage: 16.9+ MB

# %% [markdown]
# ### ship-city

# %%
data['ship-city'].value_counts()
# Out:
# ship-city
# BENGALURU                    11208
# HYDERABAD                     8077
# MUMBAI                        6125
# NEW DELHI                     5792
# CHENNAI                       5430
#                              ...
# Nashik road                      1
# PHULPUR AZAMGARH DISTRICT        1
# MUMBAI,malad  east               1
# KOTHAPALLE, E.G.Dt               1
# shimoga                          1
# Name: count, Length: 8948, dtype: int64

# %%
top_10_ship_city = data['ship-city'].value_counts()[:10]

top_10_ship_city
# Out:
# ship-city
# BENGALURU    11208
# HYDERABAD     8077
# MUMBAI        6125
# NEW DELHI     5792
# CHENNAI       5430
# PUNE          3863
# KOLKATA       2380
# GURUGRAM      1865
# THANE         1701
# LUCKNOW       1462
# Name: count, dtype: int64

# %%
top_10_ship_city.plot(kind='bar')
# Out:
# <Axes: xlabel='ship-city'>

# %% [markdown]
# ### ship-state

# %% [markdown]
# First convert all the state names to lower case.

# %%
data['ship-state'] = data['ship-state'].apply(lambda x: str(x).lower())

# %%
data['ship-state'].value_counts()
# Out:
# ship-state
# maharashtra               22272
# karnataka                 17324
# tamil nadu                11488
# telangana                 11330
# uttar pradesh             10646
# delhi                      6963
# kerala                     6577
# west bengal                5962
# andhra pradesh             5427
# gujarat                    4482
# haryana                    4410
# rajasthan                  2713
# madhya pradesh             2532
# odisha                     2136
# bihar                      2113
# punjab                     1919
# assam                      1664
# uttarakhand                1552
# jharkhand                  1457
# goa                        1137
# chhattisgarh                909
# himachal pradesh            789
# jammu & kashmir             702
# puducherry                  348
# chandigarh                  334
# manipur                     314
# andaman & nicobar           256
# meghalaya                   207
# sikkim                      205
# nagaland                    185
# tripura                     151
# arunachal pradesh           146
# new delhi                    81
# mizoram                      76
# dadra and nagar              70
# ladakh                       43
# nan                          35
# lakshadweep                   4
# orissa                        3
# rajshthan                     3
# rj                            2
# nl                            2
# rajsthan                      2
# punjab/mohali/zirakpur        1
# pb                            1
# apo                           1
# ar                            1
# pondicherry                   1
# Name: count, dtype: int64

# %%
top_10_ship_state = data['ship-state'].value_counts()[:10]

top_10_ship_state
# Out:
# ship-state
# maharashtra       22272
# karnataka         17324
# tamil nadu        11488
# telangana         11330
# uttar pradesh     10646
# delhi              6963
# kerala             6577
# west bengal        5962
# andhra pradesh     5427
# gujarat            4482
# Name: count, dtype: int64

# %%
top_10_ship_state.plot(kind='bar')
# Out:
# <Axes: xlabel='ship-state'>
